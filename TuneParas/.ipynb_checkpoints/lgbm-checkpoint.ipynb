# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
from skopt.space import Real, Categorical, Integer
import xgboost as xgb
from xgboost import XGBClassifier
import os
import gc
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn.model_selection import GridSearchCV
from skopt import BayesSearchCV
import lightgbm as lgb
from sklearn.svm import LinearSVC, SVC
import seaborn as sns
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.feature_selection import VarianceThreshold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler,PolynomialFeatures
import warnings
warnings.simplefilter('ignore')
TrainDataDir = '../data/'
ModelSaveDir = 'models'
ResultSaveDir = 'result2'
ResultSaveDir_open = 'result_open'

# %%
def loadData(Dir, DataName, index_col_flag = False):
    DataPath = os.path.join(Dir, DataName)
    if not os.path.exists(DataPath):
        print('%s does not exist!' % DataPath)
        return
    if index_col_flag:
        OriginData = pd.read_csv(DataPath,index_col=0)
    else:
        OriginData = pd.read_csv(DataPath)
    #OriginData = OriginData.sample(frac=1)  # 打乱顺序后返回
    return OriginData

# %%
# Display/plot feature importance
def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)[:50].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    plt.figure(figsize=(8, 10))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('XGBOOST Features (avg over folds)')
    plt.tight_layout()

# %%
# Splitting data
from sklearn.model_selection import train_test_split

N_FOLDS = 5
MAX_EVALS = 5

# %% [markdown]
# ### 1.加载数据

# %%
X = loadData(TrainDataDir,'df_train_oof.csv',True)

# %%
X.head()
# Out:
#    SK_ID_CURR  TARGET  lgb0819_pred  lgb0825_pred  lgb1_pred_x  lgb10_pred_x  \
# 0      100002     1.0      0.276478      0.389494     0.364570      0.348369
# 1      100003     0.0      0.017370      0.022210     0.017217      0.016348
# 2      100004     0.0      0.036509      0.036619     0.042637      0.037136
# 3      100006     0.0      0.040181      0.039508     0.043811      0.042606
# 4      100007     0.0      0.055361      0.055511     0.045627      0.051201
#
#    lgb11_pred_x  lgb2_pred_x  lgb3_pred_x  lgb4_pred_x    ...      xgb18_pred  \
# 0      0.306277     0.330778     0.509886     0.264999    ...        0.218072
# 1      0.020144     0.019681     0.028110     0.013785    ...        0.014948
# 2      0.034180     0.037103     0.073552     0.035479    ...        0.030056
# 3      0.039552     0.040146     0.081691     0.043716    ...        0.023182
# 4      0.051908     0.041010     0.091220     0.080226    ...        0.056563
#
#    xgb19_pred  xgb2_pred  xgb3_pred  xgb4_pred  xgb5_pred  xgb6_pred  \
# 0    0.163460   0.306949   0.438685   0.416051   0.245251   0.243865
# 1    0.015859   0.019579   0.044400   0.038373   0.020704   0.022618
# 2    0.031891   0.039760   0.089611   0.083794   0.036716   0.038883
# 3    0.023925   0.046730   0.074339   0.064112   0.030602   0.029732
# 4    0.050899   0.063277   0.101440   0.084579   0.048319   0.059928
#
#    xgb7_pred  xgb8_pred  xgb9_pred
# 0   0.229545   0.200648   0.183082
# 1   0.017725   0.015483   0.019762
# 2   0.030704   0.036262   0.029484
# 3   0.028022   0.025170   0.021094
# 4   0.055059   0.059462   0.055686
#
# [5 rows x 67 columns]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 307511 entries, 0 to 307510
# Data columns (total 67 columns):
# SK_ID_CURR        307511 non-null int64
# TARGET            307511 non-null float64
# lgb0819_pred      307511 non-null float64
# lgb0825_pred      307511 non-null float64
# lgb1_pred_x       307511 non-null float64
# lgb10_pred_x      307511 non-null float64
# lgb11_pred_x      307511 non-null float64
# lgb2_pred_x       307511 non-null float64
# lgb3_pred_x       307511 non-null float64
# lgb4_pred_x       307511 non-null float64
# lgb5_pred_x       307511 non-null float64
# lgb6_pred_x       307511 non-null float64
# lgb7_pred_x       307511 non-null float64
# lgb8_pred_x       307511 non-null float64
# lgb1_pred_y       307511 non-null float64
# lgb2_pred_y       307511 non-null float64
# lgb3_pred_y       307511 non-null float64
# lgb4_pred_y       307511 non-null float64
# lgb5_pred_y       307511 non-null float64
# lgb7_pred_y       307511 non-null float64
# lgb10_pred_y      307511 non-null float64
# lgb11_pred_y      307511 non-null float64
# lgb12_pred        307511 non-null float64
# lgb13_pred        307511 non-null float64
# lgb15_pred        307511 non-null float64
# lgb16_pred        307511 non-null float64
# lgb17_pred        307511 non-null float64
# lgb18_pred        307511 non-null float64
# lgb19_pred        307511 non-null float64
# lgb20_pred        307511 non-null float64
# lgb21_pred        307511 non-null float64
# lgb22_pred        307511 non-null float64
# lgb23_pred        307511 non-null float64
# lgb24_pred        307511 non-null float64
# lgb25_pred        307511 non-null float64
# lgb26_pred        307511 non-null float64
# lgb27_pred        307511 non-null float64
# lgb28_pred        307511 non-null float64
# lgb4_pred         307511 non-null float64
# lgb5_pred         307511 non-null float64
# lgb6_pred_y       307511 non-null float64
# lgb7_pred         307511 non-null float64
# lgb8_pred_y       307511 non-null float64
# lgb1_pred_open    307511 non-null float64
# lgb2_pred_open    307511 non-null float64
# lgb3_pred_open    307511 non-null float64
# lgb4_pred_open    307511 non-null float64
# lgb5_pred_open    307511 non-null float64
# xgb1_pred         307511 non-null float64
# xgb10_pred        307511 non-null float64
# xgb11_pred        307511 non-null float64
# xgb12_pred        307511 non-null float64
# xgb13_pred        307511 non-null float64
# xgb14_pred        307511 non-null float64
# xgb15_pred        307511 non-null float64
# xgb16_pred        307511 non-null float64
# xgb17_pred        307511 non-null float64
# xgb18_pred        307511 non-null float64
# xgb19_pred        307511 non-null float64
# xgb2_pred         307511 non-null float64
# xgb3_pred         307511 non-null float64
# xgb4_pred         307511 non-null float64
# xgb5_pred         307511 non-null float64
# xgb6_pred         307511 non-null float64
# xgb7_pred         307511 non-null float64
# xgb8_pred         307511 non-null float64
# xgb9_pred         307511 non-null float64
# dtypes: float64(66), int64(1)
# memory usage: 159.5 MB

# %%
X = X[~X.TARGET.isnull()]

# %%
# Sample 16000 rows (10000 for training, 6000 for testing)
features = X.sample(n = 26000, random_state = 42)

# %%
gc.enable()
del X
gc.collect()
# Out:
# 32

# %%
# Only numeric features
features = features.select_dtypes('number')
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26000 entries, 245895 to 207803
# Data columns (total 67 columns):
# SK_ID_CURR        26000 non-null int64
# TARGET            26000 non-null float64
# lgb0819_pred      26000 non-null float64
# lgb0825_pred      26000 non-null float64
# lgb1_pred_x       26000 non-null float64
# lgb10_pred_x      26000 non-null float64
# lgb11_pred_x      26000 non-null float64
# lgb2_pred_x       26000 non-null float64
# lgb3_pred_x       26000 non-null float64
# lgb4_pred_x       26000 non-null float64
# lgb5_pred_x       26000 non-null float64
# lgb6_pred_x       26000 non-null float64
# lgb7_pred_x       26000 non-null float64
# lgb8_pred_x       26000 non-null float64
# lgb1_pred_y       26000 non-null float64
# lgb2_pred_y       26000 non-null float64
# lgb3_pred_y       26000 non-null float64
# lgb4_pred_y       26000 non-null float64
# lgb5_pred_y       26000 non-null float64
# lgb7_pred_y       26000 non-null float64
# lgb10_pred_y      26000 non-null float64
# lgb11_pred_y      26000 non-null float64
# lgb12_pred        26000 non-null float64
# lgb13_pred        26000 non-null float64
# lgb15_pred        26000 non-null float64
# lgb16_pred        26000 non-null float64
# lgb17_pred        26000 non-null float64
# lgb18_pred        26000 non-null float64
# lgb19_pred        26000 non-null float64
# lgb20_pred        26000 non-null float64
# lgb21_pred        26000 non-null float64
# lgb22_pred        26000 non-null float64
# lgb23_pred        26000 non-null float64
# lgb24_pred        26000 non-null float64
# lgb25_pred        26000 non-null float64
# lgb26_pred        26000 non-null float64
# lgb27_pred        26000 non-null float64
# lgb28_pred        26000 non-null float64
# lgb4_pred         26000 non-null float64
# lgb5_pred         26000 non-null float64
# lgb6_pred_y       26000 non-null float64
# lgb7_pred         26000 non-null float64
# lgb8_pred_y       26000 non-null float64
# lgb1_pred_open    26000 non-null float64
# lgb2_pred_open    26000 non-null float64
# lgb3_pred_open    26000 non-null float64
# lgb4_pred_open    26000 non-null float64
# lgb5_pred_open    26000 non-null float64
# xgb1_pred         26000 non-null float64
# xgb10_pred        26000 non-null float64
# xgb11_pred        26000 non-null float64
# xgb12_pred        26000 non-null float64
# xgb13_pred        26000 non-null float64
# xgb14_pred        26000 non-null float64
# xgb15_pred        26000 non-null float64
# xgb16_pred        26000 non-null float64
# xgb17_pred        26000 non-null float64
# xgb18_pred        26000 non-null float64
# xgb19_pred        26000 non-null float64
# xgb2_pred         26000 non-null float64
# xgb3_pred         26000 non-null float64
# xgb4_pred         26000 non-null float64
# xgb5_pred         26000 non-null float64
# xgb6_pred         26000 non-null float64
# xgb7_pred         26000 non-null float64
# xgb8_pred         26000 non-null float64
# xgb9_pred         26000 non-null float64
# dtypes: float64(66), int64(1)
# memory usage: 13.5 MB

# %%
# Extract the labels
labels = np.array(features['TARGET'].astype(np.int32)).reshape((-1, ))
features = features.drop(columns = ['TARGET', 'SK_ID_CURR'])

# %%
# Split into training and testing data
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 6000, random_state = 50)

# %%
train_features.shape
# Out:
# (20000, 65)

# %% [markdown]
# ### 2. cross validation and early stopping(get the base line)

# %%
# Create a training and testing dataset
train_set = lgb.Dataset(data = train_features, label = train_labels)
test_set = lgb.Dataset(data = test_features, label = test_labels)

# %%
# Get default hyperparameters
model = lgb.LGBMClassifier()
default_params = model.get_params()

# Remove the number of estimators because we set this to 10000 in the cv call
del default_params['n_estimators']

# Cross validation with early stopping
cv_results = lgb.cv(default_params, train_set, num_boost_round = 10000, early_stopping_rounds = 100, 
                    metrics = 'auc', nfold = N_FOLDS, seed = 42)

# %%
print('The maximum validation ROC AUC was: {:.5f} with a standard deviation of {:.5f}.'.format(cv_results['auc-mean'][-1], cv_results['auc-stdv'][-1]))
print('The optimal number of boosting rounds (estimators) was {}.'.format(len(cv_results['auc-mean'])))
# Out:
# The maximum validation ROC AUC was: 0.79517 with a standard deviation of 0.00583.
# The optimal number of boosting rounds (estimators) was 7.

# %%
from sklearn.metrics import roc_auc_score

# %%
# Optimal number of esimators found in cv
model.n_estimators = len(cv_results['auc-mean'])

# Train and make predicions with model
model.fit(train_features, train_labels)
preds = model.predict_proba(test_features)[:, 1]
baseline_auc = roc_auc_score(test_labels, preds)

print('The baseline model scores {:.5f} ROC AUC on the test set.'.format(baseline_auc))
# Out:
# The baseline model scores 0.79627 ROC AUC on the test set.

# %% [markdown]
# ### 3.Objective function

# %%
def objective(hyperparameters, iteration):
    """Objective function for grid and random search. Returns
       the cross validation score from a set of hyperparameters."""
    
    # Number of estimators will be found using early stopping
    if 'n_estimators' in hyperparameters.keys():
        del hyperparameters['n_estimators']
    
     # Perform n_folds cross validation
    cv_results = lgb.cv(hyperparameters, train_set, num_boost_round = 10000, nfold = N_FOLDS, 
                        early_stopping_rounds = 100, metrics = 'auc', seed = 42)
    
    # results to retun
    score = cv_results['auc-mean'][-1]
    estimators = len(cv_results['auc-mean'])
    hyperparameters['n_estimators'] = estimators 
    
    return [score, hyperparameters, iteration]

# %%
score, params, iteration = objective(default_params, 1)

print('The cross-validation ROC AUC was {:.5f}.'.format(score))
# Out:
# The cross-validation ROC AUC was 0.79517.

# %% [markdown]
# ### 4.Hyperparameters for GBM

# %%
# Create a default model
model = lgb.LGBMModel()
model.get_params()
# Out:
# {'boosting_type': 'gbdt',
#  'class_weight': None,
#  'colsample_bytree': 1.0,
#  'learning_rate': 0.1,
#  'max_depth': -1,
#  'min_child_samples': 20,
#  'min_child_weight': 0.001,
#  'min_split_gain': 0.0,
#  'n_estimators': 100,
#  'n_jobs': -1,
#  'num_leaves': 31,
#  'objective': None,
#  'random_state': None,
#  'reg_alpha': 0.0,
#  'reg_lambda': 0.0,
#  'silent': True,
#  'subsample': 1.0,
#  'subsample_for_bin': 200000,
#  'subsample_freq': 0}

# %%
# Hyperparameter grid
param_grid = {
    'boosting_type': ['gbdt', 'goss', 'dart'],
    'num_leaves': list(range(20, 150)),
    'learning_rate': list(np.logspace(np.log10(0.005), np.log10(0.5), base = 10, num = 1000)),
    'subsample_for_bin': list(range(20000, 300000, 20000)),
    'min_child_samples': list(range(20, 500, 5)),
    'reg_alpha': list(np.linspace(0, 1)),
    'reg_lambda': list(np.linspace(0, 1)),
    'colsample_bytree': list(np.linspace(0.6, 1, 10)),
    'subsample': list(np.linspace(0.5, 1, 100)),
    'is_unbalance': [True, False]
}

# %% [markdown]
# One aspect to note is that if boosting_type is goss, then we cannot use subsample (which refers to training on only a fraction of the rows in the training data, a technique known as stochastic gradient boosting). Therefore, we will need a line of logic in our algorithm that sets the subsample to 1.0 (which means use all the rows) if boosting_type=goss. As an example below, if we randomly select a set of hyperparameters, and the boosting type is "goss", then we set the subsample to 1.0.

# %%
import random

random.seed(50)

# Randomly sample a boosting type
boosting_type = random.sample(param_grid['boosting_type'], 1)[0]

# Set subsample depending on boosting type
subsample = 1.0 if boosting_type == 'goss' else random.sample(param_grid['subsample'], 1)[0]

print('Boosting type: ', boosting_type)
print('Subsample ratio: ', subsample)
# Out:
# Boosting type:  goss
# Subsample ratio:  1.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# Learning rate histogram
plt.hist(param_grid['learning_rate'], bins = 20, color = 'r', edgecolor = 'k');
plt.xlabel('Learning Rate', size = 14); plt.ylabel('Count', size = 14); plt.title('Learning Rate Distribution', size = 18);

# %% [markdown]
# ### 5.Grid Search Implementation

# %%
import itertools

def grid_search(param_grid, max_evals = MAX_EVALS):
    """Grid search algorithm (with limit on max evals)"""
    
    # Dataframe to store results
    results = pd.DataFrame(columns = ['score', 'params', 'iteration'],
                              index = list(range(MAX_EVALS)))
    
    # https://codereview.stackexchange.com/questions/171173/list-all-possible-permutations-from-a-python-dictionary-of-lists
    keys, values = zip(*param_grid.items())
    
    i = 0
    
    # Iterate through every possible combination of hyperparameters
    for v in itertools.product(*values):
        print('iter:%d'%i)
        # Create a hyperparameter dictionary
        hyperparameters = dict(zip(keys, v))
        
        # Set the subsample ratio accounting for boosting type
        hyperparameters['subsample'] = 1.0 if hyperparameters['boosting_type'] == 'goss' else hyperparameters['subsample']
        
        # Evalute the hyperparameters
        eval_results = objective(hyperparameters, i)
        
        results.loc[i, :] = eval_results
        print('result:',eval_results)
        i += 1
        
        # Normally would not limit iterations
        if i > MAX_EVALS:
            break
       
    # Sort with best score on top
    results.sort_values('score', ascending = False, inplace = True)
    results.reset_index(inplace = True)
    
    return results

# %%
grid_results = grid_search(param_grid)

print('The best validation score was {:.5f}'.format(grid_results.loc[0, 'score']))
print('\nThe best hyperparameters were:')

import pprint
pprint.pprint(grid_results.loc[0, 'params'])
# Out:
# iter:0
# result: [0.7977216423333395, {'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.004999999999999999, 'subsample_for_bin': 20000, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'colsample_bytree': 0.6, 'subsample': 0.5, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 118}, 0]
# iter:1
# result: [0.7977216423333395, {'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.004999999999999999, 'subsample_for_bin': 20000, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'colsample_bytree': 0.6, 'subsample': 0.5, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 118}, 1]
# iter:2
# result: [0.7977216423333395, {'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.004999999999999999, 'subsample_for_bin': 20000, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'colsample_bytree': 0.6, 'subsample': 0.5050505050505051, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 118}, 2]
# iter:3
# result: [0.7977216423333395, {'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.004999999999999999, 'subsample_for_bin': 20000, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'colsample_bytree': 0.6, 'subsample': 0.5050505050505051, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 118}, 3]
# iter:4
# result: [0.7977216423333395, {'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.004999999999999999, 'subsample_for_bin': 20000, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'colsample_bytree': 0.6, 'subsample': 0.51010101010101, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 118}, 4]
# iter:5
# result: [0.7977216423333395, {'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.004999999999999999, 'subsample_for_bin': 20000, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'colsample_bytree': 0.6, 'subsample': 0.51010101010101, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 118}, 5]
# The best validation score was 0.79772
#
# The best hyperparameters were:
# {'boosting_type': 'gbdt',
#  'colsample_bytree': 0.6,
#  'is_unbalance': True,
#  'learning_rate': 0.004999999999999999,
#  'metric': 'auc',
#  'min_child_samples': 20,
#  'n_estimators': 118,
#  'num_leaves': 20,
#  'reg_alpha': 0.0,
#  'reg_lambda': 0.0,
#  'subsample': 0.5,
#  'subsample_for_bin': 20000,
#  'verbose': 1}

# %%
pd.options.display.max_colwidth = 1000
grid_results['params'].values
# Out:
# array([{'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.004999999999999999, 'subsample_for_bin': 20000, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'colsample_bytree': 0.6, 'subsample': 0.5, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 118},
#        {'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.004999999999999999, 'subsample_for_bin': 20000, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'colsample_bytree': 0.6, 'subsample': 0.5, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 118},
#        {'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.004999999999999999, 'subsample_for_bin': 20000, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'colsample_bytree': 0.6, 'subsample': 0.5050505050505051, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 118},
#        {'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.004999999999999999, 'subsample_for_bin': 20000, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'colsample_bytree': 0.6, 'subsample': 0.5050505050505051, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 118},
#        {'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.004999999999999999, 'subsample_for_bin': 20000, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'colsample_bytree': 0.6, 'subsample': 0.51010101010101, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 118},
#        {'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.004999999999999999, 'subsample_for_bin': 20000, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'colsample_bytree': 0.6, 'subsample': 0.51010101010101, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 118}],
#       dtype=object)

# %% [markdown]
# ### 6.Random Search

# %%
random.seed(50)

# Randomly sample from dictionary
random_params = {k: random.sample(v, 1)[0] for k, v in param_grid.items()}
# Deal with subsample ratio
random_params['subsample'] = 1.0 if random_params['boosting_type'] == 'goss' else random_params['subsample']

random_params
# Out:
# {'boosting_type': 'goss',
#  'num_leaves': 88,
#  'learning_rate': 0.027778881111994384,
#  'subsample_for_bin': 220000,
#  'min_child_samples': 175,
#  'reg_alpha': 0.8979591836734693,
#  'reg_lambda': 0.6122448979591836,
#  'colsample_bytree': 0.8222222222222222,
#  'subsample': 1.0,
#  'is_unbalance': False}

# %%
def random_search(param_grid, max_evals = MAX_EVALS):
    """Random search for hyperparameter optimization"""
    
    # Dataframe for results
    results = pd.DataFrame(columns = ['score', 'params', 'iteration'],
                                  index = list(range(MAX_EVALS)))
    
    # Keep searching until reach max evaluations
    for i in range(MAX_EVALS):
        print('iter:%d'%i)
        # Choose random hyperparameters
        hyperparameters = {k: random.sample(v, 1)[0] for k, v in param_grid.items()}
        hyperparameters['subsample'] = 1.0 if hyperparameters['boosting_type'] == 'goss' else hyperparameters['subsample']

        # Evaluate randomly selected hyperparameters
        eval_results = objective(hyperparameters, i)
        print(eval_results)
        results.loc[i, :] = eval_results
    
    # Sort with best score on top
    results.sort_values('score', ascending = False, inplace = True)
    results.reset_index(inplace = True)
    return results

# %%
random_results = random_search(param_grid)

print('The best validation score was {:.5f}'.format(random_results.loc[0, 'score']))
print('\nThe best hyperparameters were:')

import pprint
pprint.pprint(random_results.loc[0, 'params'])
# Out:
# iter:0
# [0.7771635793048038, {'boosting_type': 'gbdt', 'num_leaves': 41, 'learning_rate': 0.40260198354127363, 'subsample_for_bin': 60000, 'min_child_samples': 240, 'reg_alpha': 0.12244897959183673, 'reg_lambda': 0.44897959183673464, 'colsample_bytree': 0.8222222222222222, 'subsample': 0.6414141414141414, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 2}, 0]
# iter:1
# [0.7937263515067159, {'boosting_type': 'gbdt', 'num_leaves': 104, 'learning_rate': 0.08633904519421778, 'subsample_for_bin': 200000, 'min_child_samples': 290, 'reg_alpha': 0.8163265306122448, 'reg_lambda': 0.1020408163265306, 'colsample_bytree': 0.6444444444444444, 'subsample': 0.9444444444444444, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 9}, 1]
# iter:2
# [0.7941006099716869, {'boosting_type': 'dart', 'num_leaves': 130, 'learning_rate': 0.005116582891651224, 'subsample_for_bin': 80000, 'min_child_samples': 235, 'reg_alpha': 0.3469387755102041, 'reg_lambda': 0.5510204081632653, 'colsample_bytree': 0.6444444444444444, 'subsample': 0.6262626262626263, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 109}, 2]
# iter:3
# [0.7956110831879252, {'boosting_type': 'goss', 'num_leaves': 137, 'learning_rate': 0.009062087736871187, 'subsample_for_bin': 100000, 'min_child_samples': 415, 'reg_alpha': 0.26530612244897955, 'reg_lambda': 0.6938775510204082, 'colsample_bytree': 1.0, 'subsample': 1.0, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 77}, 3]
# iter:4
# [0.788754672980813, {'boosting_type': 'dart', 'num_leaves': 50, 'learning_rate': 0.2797162853084688, 'subsample_for_bin': 220000, 'min_child_samples': 365, 'reg_alpha': 0.6326530612244897, 'reg_lambda': 0.5510204081632653, 'colsample_bytree': 0.9555555555555555, 'subsample': 0.8434343434343434, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 3}, 4]
# The best validation score was 0.79561
#
# The best hyperparameters were:
# {'boosting_type': 'goss',
#  'colsample_bytree': 1.0,
#  'is_unbalance': False,
#  'learning_rate': 0.009062087736871187,
#  'metric': 'auc',
#  'min_child_samples': 415,
#  'n_estimators': 77,
#  'num_leaves': 137,
#  'reg_alpha': 0.26530612244897955,
#  'reg_lambda': 0.6938775510204082,
#  'subsample': 1.0,
#  'subsample_for_bin': 100000,
#  'verbose': 1}

# %% [markdown]
# ### 7.查看我们的自己模型的baseline

# %%
hyperparameters_own = {  #'random_search_runs': 0,
                      'device': 'cpu', # gpu cpu
                      'num_threads':-1,
                      'boosting_type': 'gbdt',
                      'objective': 'binary',
                      'metric': 'auc',
                      'learning_rate': 0.01291549665014884,
                      'max_bin': 300,
                      'max_depth': -1,
                      'num_leaves': 30,
                      'min_child_samples': 10,
                      'subsample': 1.0,
                      'subsample_freq': 1,
                      'colsample_bytree': 0.01,
                      'min_gain_to_split': 0.5,
                      'reg_lambda': 4,
                      'reg_alpha': 0.001,
                      'scale_pos_weight': 1,  
                      'is_unbalance': False}

# %%
score, params, iteration = objective(hyperparameters_own, 1)

print('The cross-validation ROC AUC was {:.5f}.'.format(score))
# Out:
# The cross-validation ROC AUC was 0.79991.

# %% [markdown]
# ### 8.增大迭代次数并将结果写进文件

# %%
import csv

# Create file and open connection
out_file = 'random_search_trials.csv'
of_connection = open(out_file, 'w')
writer = csv.writer(of_connection)

# Write column names
headers = ['score', 'hyperparameters', 'iteration']
writer.writerow(headers)
of_connection.close()

# %%
def random_search(param_grid, out_file, max_evals = MAX_EVALS):
    """Random search for hyperparameter optimization. 
       Writes result of search to csv file every search iteration."""
    
    
    # Dataframe for results
    results = pd.DataFrame(columns = ['score', 'params', 'iteration'],
                                  index = list(range(MAX_EVALS)))
    for i in range(MAX_EVALS):
        print('iter:%d'%i)
        # Choose random hyperparameters
        random_params = {k: random.sample(v, 1)[0] for k, v in param_grid.items()}
        random_params['subsample'] = 1.0 if random_params['boosting_type'] == 'goss' else random_params['subsample']

        # Evaluate randomly selected hyperparameters
        eval_results = objective(random_params, i)
        results.loc[i, :] = eval_results
        print(eval_results)
        # open connection (append option) and write results
        of_connection = open(out_file, 'a')
        writer = csv.writer(of_connection)
        writer.writerow(eval_results)
        
        # make sure to close connection
        of_connection.close()
        
    # Sort with best score on top
    results.sort_values('score', ascending = False, inplace = True)
    results.reset_index(inplace = True)

    return results

# %%
def grid_search(param_grid, out_file, max_evals = MAX_EVALS):
    """Grid search algorithm (with limit on max evals)
       Writes result of search to csv file every search iteration."""
    
    # Dataframe to store results
    results = pd.DataFrame(columns = ['score', 'params', 'iteration'],
                              index = list(range(MAX_EVALS)))
    
    # https://codereview.stackexchange.com/questions/171173/list-all-possible-permutations-from-a-python-dictionary-of-lists
    keys, values = zip(*param_grid.items())
    
    i = 0
    
    # Iterate through every possible combination of hyperparameters
    for v in itertools.product(*values):
        print('iter:%d'%i)
        # Select the hyperparameters
        parameters = dict(zip(keys, v))
        
        # Set the subsample ratio accounting for boosting type
        parameters['subsample'] = 1.0 if parameters['boosting_type'] == 'goss' else parameters['subsample']
        
        # Evalute the hyperparameters
        eval_results = objective(parameters, i)
        print(eval_results)
        results.loc[i, :] = eval_results
        
        i += 1
        
        # open connection (append option) and write results
        of_connection = open(out_file, 'a')
        writer = csv.writer(of_connection)
        writer.writerow(eval_results)
        
        # make sure to close connection
        of_connection.close()
        
        # Normally would not limit iterations
        if i > MAX_EVALS:
            break
       
    # Sort with best score on top
    results.sort_values('score', ascending = False, inplace = True)
    results.reset_index(inplace = True)
    
    return results

# %%
MAX_EVALS = 1000
# Create file and open connection
out_file = 'random_search_trials_1000.csv'
of_connection = open(out_file, 'w')
writer = csv.writer(of_connection)
# Write column names
headers = ['score', 'hyperparameters', 'iteration']
writer.writerow(headers)
of_connection.close()
random_results = random_search(param_grid, out_file)
# Out:
# iter:0
# [0.7949126420544367, {'boosting_type': 'goss', 'num_leaves': 96, 'learning_rate': 0.007747475196573157, 'subsample_for_bin': 280000, 'min_child_samples': 255, 'reg_alpha': 0.9795918367346939, 'reg_lambda': 0.673469387755102, 'colsample_bytree': 0.6888888888888889, 'subsample': 1.0, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 88}, 0]
# iter:1
# [0.7964630697799893, {'boosting_type': 'gbdt', 'num_leaves': 125, 'learning_rate': 0.04655206743534537, 'subsample_for_bin': 260000, 'min_child_samples': 435, 'reg_alpha': 0.6938775510204082, 'reg_lambda': 0.2857142857142857, 'colsample_bytree': 0.6888888888888889, 'subsample': 0.9646464646464648, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 10}, 1]
# iter:2
# [0.7894564609491652, {'boosting_type': 'gbdt', 'num_leaves': 85, 'learning_rate': 0.02949448212754248, 'subsample_for_bin': 260000, 'min_child_samples': 175, 'reg_alpha': 0.42857142857142855, 'reg_lambda': 0.04081632653061224, 'colsample_bytree': 0.9555555555555555, 'subsample': 0.5303030303030303, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 23}, 2]
# iter:3
# [0.7940979042560882, {'boosting_type': 'dart', 'num_leaves': 80, 'learning_rate': 0.12484392144421633, 'subsample_for_bin': 100000, 'min_child_samples': 355, 'reg_alpha': 0.5306122448979591, 'reg_lambda': 0.5918367346938775, 'colsample_bytree': 1.0, 'subsample': 0.7676767676767677, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 6}, 3]
# iter:4
# [0.7919561615827995, {'boosting_type': 'goss', 'num_leaves': 42, 'learning_rate': 0.03340371957847807, 'subsample_for_bin': 40000, 'min_child_samples': 250, 'reg_alpha': 0.061224489795918366, 'reg_lambda': 1.0, 'colsample_bytree': 0.6, 'subsample': 1.0, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 19}, 4]
# iter:5
# [0.795843775884103, {'boosting_type': 'dart', 'num_leaves': 22, 'learning_rate': 0.02126173167264341, 'subsample_for_bin': 120000, 'min_child_samples': 240, 'reg_alpha': 0.6938775510204082, 'reg_lambda': 0.836734693877551, 'colsample_bytree': 0.9555555555555555, 'subsample': 0.8181818181818182, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 30}, 5]
# iter:6
# [0.7911567253056264, {'boosting_type': 'goss', 'num_leaves': 60, 'learning_rate': 0.038005888089776646, 'subsample_for_bin': 80000, 'min_child_samples': 90, 'reg_alpha': 0.8571428571428571, 'reg_lambda': 0.1020408163265306, 'colsample_bytree': 0.6, 'subsample': 1.0, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 27}, 6]
# iter:7
# [0.7970826044237562, {'boosting_type': 'gbdt', 'num_leaves': 56, 'learning_rate': 0.005741562072717555, 'subsample_for_bin': 100000, 'min_child_samples': 455, 'reg_alpha': 0.9591836734693877, 'reg_lambda': 0.44897959183673464, 'colsample_bytree': 0.6, 'subsample': 0.6111111111111112, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 36}, 7]
# iter:8
# [0.7720687134246477, {'boosting_type': 'gbdt', 'num_leaves': 98, 'learning_rate': 0.1344000510768803, 'subsample_for_bin': 200000, 'min_child_samples': 35, 'reg_alpha': 0.18367346938775508, 'reg_lambda': 0.6326530612244897, 'colsample_bytree': 0.8666666666666667, 'subsample': 0.7777777777777778, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 9}, 8]
# iter:9
# [0.7931912858595789, {'boosting_type': 'dart', 'num_leaves': 59, 'learning_rate': 0.014302977675878709, 'subsample_for_bin': 280000, 'min_child_samples': 35, 'reg_alpha': 0.673469387755102, 'reg_lambda': 0.7755102040816326, 'colsample_bytree': 0.7777777777777778, 'subsample': 0.9191919191919192, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 141}, 9]
# iter:10
# [0.7955702550276822, {'boosting_type': 'goss', 'num_leaves': 103, 'learning_rate': 0.006152620021796307, 'subsample_for_bin': 60000, 'min_child_samples': 360, 'reg_alpha': 0.6122448979591836, 'reg_lambda': 0.36734693877551017, 'colsample_bytree': 0.6888888888888889, 'subsample': 1.0, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 77}, 10]
# iter:11
# [0.783391027393314, {'boosting_type': 'goss', 'num_leaves': 85, 'learning_rate': 0.056496696901661106, 'subsample_for_bin': 180000, 'min_child_samples': 95, 'reg_alpha': 0.12244897959183673, 'reg_lambda': 0.7142857142857142, 'colsample_bytree': 0.6444444444444444, 'subsample': 1.0, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 14}, 11]
# iter:12
# [0.7784843528886141, {'boosting_type': 'goss', 'num_leaves': 144, 'learning_rate': 0.30112706007309636, 'subsample_for_bin': 160000, 'min_child_samples': 180, 'reg_alpha': 0.36734693877551017, 'reg_lambda': 0.8571428571428571, 'colsample_bytree': 1.0, 'subsample': 1.0, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 4}, 12]
# iter:13
# [0.7898064336023053, {'boosting_type': 'gbdt', 'num_leaves': 70, 'learning_rate': 0.016198713147640983, 'subsample_for_bin': 100000, 'min_child_samples': 175, 'reg_alpha': 0.061224489795918366, 'reg_lambda': 0.7142857142857142, 'colsample_bytree': 0.9111111111111111, 'subsample': 0.6161616161616161, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 33}, 13]
# iter:14
# [0.7810536263304024, {'boosting_type': 'gbdt', 'num_leaves': 90, 'learning_rate': 0.15221361060321512, 'subsample_for_bin': 140000, 'min_child_samples': 20, 'reg_alpha': 0.9387755102040816, 'reg_lambda': 0.36734693877551017, 'colsample_bytree': 0.9555555555555555, 'subsample': 0.5606060606060606, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 4}, 14]
# iter:15
# [0.788122497342958, {'boosting_type': 'dart', 'num_leaves': 131, 'learning_rate': 0.4730924097360998, 'subsample_for_bin': 80000, 'min_child_samples': 330, 'reg_alpha': 0.5102040816326531, 'reg_lambda': 0.9795918367346939, 'colsample_bytree': 0.9555555555555555, 'subsample': 0.5303030303030303, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 2}, 15]
# iter:16
# [0.7929116873118093, {'boosting_type': 'goss', 'num_leaves': 50, 'learning_rate': 0.010502491208269574, 'subsample_for_bin': 60000, 'min_child_samples': 230, 'reg_alpha': 0.6530612244897959, 'reg_lambda': 0.24489795918367346, 'colsample_bytree': 0.6, 'subsample': 1.0, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 96}, 16]
# iter:17
# [0.7925774126796664, {'boosting_type': 'goss', 'num_leaves': 93, 'learning_rate': 0.14204418450916512, 'subsample_for_bin': 220000, 'min_child_samples': 315, 'reg_alpha': 0.8163265306122448, 'reg_lambda': 0.8163265306122448, 'colsample_bytree': 0.9555555555555555, 'subsample': 1.0, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 8}, 17]
# iter:18
# [0.795684753815622, {'boosting_type': 'gbdt', 'num_leaves': 29, 'learning_rate': 0.026773104496368032, 'subsample_for_bin': 20000, 'min_child_samples': 140, 'reg_alpha': 0.1020408163265306, 'reg_lambda': 0.2857142857142857, 'colsample_bytree': 0.6888888888888889, 'subsample': 0.5656565656565656, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 19}, 18]
# iter:19
# [0.7827087275265314, {'boosting_type': 'gbdt', 'num_leaves': 85, 'learning_rate': 0.1550463317965963, 'subsample_for_bin': 160000, 'min_child_samples': 155, 'reg_alpha': 0.2040816326530612, 'reg_lambda': 0.4693877551020408, 'colsample_bytree': 0.8666666666666667, 'subsample': 0.898989898989899, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 3}, 19]
# iter:20
# [0.7835834529974817, {'boosting_type': 'gbdt', 'num_leaves': 41, 'learning_rate': 0.33790905840805546, 'subsample_for_bin': 260000, 'min_child_samples': 250, 'reg_alpha': 0.5102040816326531, 'reg_lambda': 0.7959183673469387, 'colsample_bytree': 0.6, 'subsample': 0.5252525252525253, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 5}, 20]
# iter:21
# [0.787928143045718, {'boosting_type': 'goss', 'num_leaves': 100, 'learning_rate': 0.03679907237632883, 'subsample_for_bin': 260000, 'min_child_samples': 95, 'reg_alpha': 0.673469387755102, 'reg_lambda': 0.6122448979591836, 'colsample_bytree': 0.9111111111111111, 'subsample': 1.0, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 17}, 21]
# iter:22
# [0.7839122492989485, {'boosting_type': 'dart', 'num_leaves': 50, 'learning_rate': 0.2092144253950791, 'subsample_for_bin': 240000, 'min_child_samples': 95, 'reg_alpha': 0.3061224489795918, 'reg_lambda': 0.8571428571428571, 'colsample_bytree': 0.6888888888888889, 'subsample': 0.8434343434343434, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 3}, 22]
# iter:23
# [0.7941389142587613, {'boosting_type': 'goss', 'num_leaves': 94, 'learning_rate': 0.22626931390850843, 'subsample_for_bin': 100000, 'min_child_samples': 355, 'reg_alpha': 0.8571428571428571, 'reg_lambda': 0.7346938775510203, 'colsample_bytree': 0.8666666666666667, 'subsample': 1.0, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 5}, 23]
# iter:24
# [0.7912843515802817, {'boosting_type': 'dart', 'num_leaves': 59, 'learning_rate': 0.08169269389049305, 'subsample_for_bin': 60000, 'min_child_samples': 40, 'reg_alpha': 0.673469387755102, 'reg_lambda': 0.26530612244897955, 'colsample_bytree': 0.8666666666666667, 'subsample': 0.7474747474747475, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 14}, 24]
# iter:25
# [0.7923683753260986, {'boosting_type': 'goss', 'num_leaves': 115, 'learning_rate': 0.024641247850202563, 'subsample_for_bin': 100000, 'min_child_samples': 240, 'reg_alpha': 0.3877551020408163, 'reg_lambda': 0.6122448979591836, 'colsample_bytree': 0.6888888888888889, 'subsample': 1.0, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 24}, 25]
# iter:26
# [0.7944800150681568, {'boosting_type': 'dart', 'num_leaves': 105, 'learning_rate': 0.06577928120228521, 'subsample_for_bin': 220000, 'min_child_samples': 295, 'reg_alpha': 0.5306122448979591, 'reg_lambda': 0.6122448979591836, 'colsample_bytree': 0.9555555555555555, 'subsample': 0.51010101010101, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 10}, 26]
# iter:27
# [0.7912993000878348, {'boosting_type': 'gbdt', 'num_leaves': 56, 'learning_rate': 0.09778253579329745, 'subsample_for_bin': 200000, 'min_child_samples': 215, 'reg_alpha': 0.5918367346938775, 'reg_lambda': 0.836734693877551, 'colsample_bytree': 0.8222222222222222, 'subsample': 0.5202020202020202, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 7}, 27]
# iter:28
# [0.7925853573925513, {'boosting_type': 'gbdt', 'num_leaves': 60, 'learning_rate': 0.015902760076664597, 'subsample_for_bin': 180000, 'min_child_samples': 245, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'colsample_bytree': 0.8222222222222222, 'subsample': 0.6565656565656566, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 51}, 28]
# iter:29
# [0.789076853333674, {'boosting_type': 'dart', 'num_leaves': 122, 'learning_rate': 0.1586614817367488, 'subsample_for_bin': 220000, 'min_child_samples': 290, 'reg_alpha': 0.42857142857142855, 'reg_lambda': 0.673469387755102, 'colsample_bytree': 1.0, 'subsample': 0.7171717171717171, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 5}, 29]
# iter:30
# [0.7886676044812067, {'boosting_type': 'goss', 'num_leaves': 134, 'learning_rate': 0.39342857534684234, 'subsample_for_bin': 220000, 'min_child_samples': 430, 'reg_alpha': 0.24489795918367346, 'reg_lambda': 0.22448979591836732, 'colsample_bytree': 1.0, 'subsample': 1.0, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 3}, 30]
# iter:31
# [0.7957468981399629, {'boosting_type': 'goss', 'num_leaves': 104, 'learning_rate': 0.018601183407065337, 'subsample_for_bin': 120000, 'min_child_samples': 390, 'reg_alpha': 0.5510204081632653, 'reg_lambda': 0.836734693877551, 'colsample_bytree': 0.6, 'subsample': 1.0, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 35}, 31]
# iter:32
# [0.7946221462990607, {'boosting_type': 'dart', 'num_leaves': 82, 'learning_rate': 0.007964751062860613, 'subsample_for_bin': 20000, 'min_child_samples': 360, 'reg_alpha': 0.44897959183673464, 'reg_lambda': 0.7959183673469387, 'colsample_bytree': 0.9111111111111111, 'subsample': 0.5353535353535354, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 218}, 32]
# iter:33
# [0.7944845623382997, {'boosting_type': 'dart', 'num_leaves': 142, 'learning_rate': 0.011463846564328242, 'subsample_for_bin': 100000, 'min_child_samples': 280, 'reg_alpha': 0.6326530612244897, 'reg_lambda': 0.32653061224489793, 'colsample_bytree': 0.7333333333333333, 'subsample': 0.5151515151515151, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 97}, 33]
# iter:34
# [0.7908250008107908, {'boosting_type': 'dart', 'num_leaves': 42, 'learning_rate': 0.11074276168631794, 'subsample_for_bin': 120000, 'min_child_samples': 65, 'reg_alpha': 0.9387755102040816, 'reg_lambda': 0.4693877551020408, 'colsample_bytree': 0.8222222222222222, 'subsample': 0.5353535353535354, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 9}, 34]
# iter:35
# [0.7959083635219377, {'boosting_type': 'gbdt', 'num_leaves': 23, 'learning_rate': 0.039433643078070756, 'subsample_for_bin': 40000, 'min_child_samples': 390, 'reg_alpha': 0.36734693877551017, 'reg_lambda': 0.5102040816326531, 'colsample_bytree': 0.6444444444444444, 'subsample': 0.9242424242424243, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 21}, 35]
# iter:36
# [0.795458159782041, {'boosting_type': 'goss', 'num_leaves': 127, 'learning_rate': 0.01084691759192592, 'subsample_for_bin': 180000, 'min_child_samples': 350, 'reg_alpha': 0.16326530612244897, 'reg_lambda': 0.2857142857142857, 'colsample_bytree': 0.7777777777777778, 'subsample': 1.0, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 59}, 36]
# iter:37
# [0.7921051822567861, {'boosting_type': 'goss', 'num_leaves': 129, 'learning_rate': 0.1731847088685866, 'subsample_for_bin': 140000, 'min_child_samples': 350, 'reg_alpha': 0.5714285714285714, 'reg_lambda': 0.6938775510204082, 'colsample_bytree': 0.7333333333333333, 'subsample': 1.0, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 6}, 37]
# iter:38
# [0.7820315284553113, {'boosting_type': 'dart', 'num_leaves': 77, 'learning_rate': 0.23694398048588264, 'subsample_for_bin': 100000, 'min_child_samples': 185, 'reg_alpha': 0.9183673469387754, 'reg_lambda': 0.8571428571428571, 'colsample_bytree': 0.8222222222222222, 'subsample': 0.7323232323232324, 'is_unbalance': True, 'metric': 'auc', 'verbose': 1, 'n_estimators': 4}, 38]
# iter:39
# [0.7879266449834732, {'boosting_type': 'dart', 'num_leaves': 138, 'learning_rate': 0.3167902496329125, 'subsample_for_bin': 200000, 'min_child_samples': 335, 'reg_alpha': 0.4897959183673469, 'reg_lambda': 0.2857142857142857, 'colsample_bytree': 1.0, 'subsample': 0.797979797979798, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 2}, 39]
# iter:40
# [0.7855319809672354, {'boosting_type': 'goss', 'num_leaves': 109, 'learning_rate': 0.41965647490831814, 'subsample_for_bin': 260000, 'min_child_samples': 440, 'reg_alpha': 0.3061224489795918, 'reg_lambda': 0.9591836734693877, 'colsample_bytree': 0.6888888888888889, 'subsample': 1.0, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 3}, 40]
# iter:41
# [0.7870940104317925, {'boosting_type': 'dart', 'num_leaves': 91, 'learning_rate': 0.08321300882429516, 'subsample_for_bin': 180000, 'min_child_samples': 160, 'reg_alpha': 0.12244897959183673, 'reg_lambda': 1.0, 'colsample_bytree': 0.6888888888888889, 'subsample': 0.8535353535353536, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 14}, 41]
# iter:42
# [0.796288459884081, {'boosting_type': 'dart', 'num_leaves': 44, 'learning_rate': 0.01868712871195532, 'subsample_for_bin': 40000, 'min_child_samples': 470, 'reg_alpha': 0.5102040816326531, 'reg_lambda': 0.673469387755102, 'colsample_bytree': 0.8666666666666667, 'subsample': 0.6565656565656566, 'is_unbalance': False, 'metric': 'auc', 'verbose': 1, 'n_estimators': 53}, 42]
# iter:43
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-347b778bd715> in <module>()
#       8 writer.writerow(headers)
#       9 of_connection.close()
# ---> 10 random_results = random_search(param_grid, out_file)
#
# <ipython-input-35-5192a02cf50b> in random_search(param_grid, out_file, max_evals)
#      14
#      15         # Evaluate randomly selected hyperparameters
# ---> 16         eval_results = objective(random_params, i)
#      17         results.loc[i, :] = eval_results
#      18         print(eval_results)
#
# <ipython-input-20-c3d4e297cf94> in objective(hyperparameters, iteration)
#       9      # Perform n_folds cross validation
#      10     cv_results = lgb.cv(hyperparameters, train_set, num_boost_round = 10000, nfold = N_FOLDS,
# ---> 11                         early_stopping_rounds = 100, metrics = 'auc', seed = 42)
#      12
#      13     # results to retun
#
# D:\SoftWares\Anaconda3\lib\site-packages\lightgbm\engine.py in cv(params, train_set, num_boost_round, folds, nfold, stratified, shuffle, metrics, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, fpreproc, verbose_eval, show_stdv, seed, callbacks)
#     449                                     end_iteration=num_boost_round,
#     450                                     evaluation_result_list=None))
# --> 451         cvfolds.update(fobj=fobj)
#     452         res = _agg_cv_result(cvfolds.eval_valid(feval))
#     453         for _, key, mean, _, std in res:
#
# D:\SoftWares\Anaconda3\lib\site-packages\lightgbm\engine.py in handlerFunction(*args, **kwargs)
#     247             ret = []
#     248             for booster in self.boosters:
# --> 249                 ret.append(getattr(booster, name)(*args, **kwargs))
#     250             return ret
#     251         return handlerFunction
#
# D:\SoftWares\Anaconda3\lib\site-packages\lightgbm\basic.py in update(self, train_set, fobj)
#    1526             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1527                 self.handle,
# -> 1528                 ctypes.byref(is_finished)))
#    1529             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1530             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
# Create file and open connection
out_file = 'grid_search_trials_1000.csv'
of_connection = open(out_file, 'w')
writer = csv.writer(of_connection)
# Write column names
headers = ['score', 'hyperparameters', 'iteration']
writer.writerow(headers)
of_connection.close()
grid_results = grid_search(param_grid, out_file)

# %% [markdown]
# ### 9.贝叶斯优化

# %%
def status_print(optim_result):
    """Status callback durring bayesian hyperparameter search"""
    
    # Get all the models tested so far in DataFrame format
    all_models = pd.DataFrame(bayes_cv_tuner.cv_results_)    
    
    # Get current parameters and the best parameters    
    best_params = pd.Series(bayes_cv_tuner.best_params_)
    print('Model #{}\nBest ROC-AUC: {}\nBest params: {}\n'.format(
        len(all_models),
        np.round(bayes_cv_tuner.best_score_, 4),
        bayes_cv_tuner.best_params_
    ))
    
    # Save all model results
    clf_name = bayes_cv_tuner.estimator.__class__.__name__
    all_models.to_csv(clf_name+"_cv_results.csv")

# %%
bayes_cv_tuner = BayesSearchCV(
    estimator = lgb.LGBMClassifier(
        application='binary',
        reg_alpha=0.04,
        reg_lambda=0.073,
        min_split_gain=0.0222415,
        min_child_weight=40,
        colsample_bytree=0.9497036,
        subsample=0.8715623,
        max_depth=8,
        metric='auc',
        n_jobs=-1,
        verbose=0
    ),
    search_spaces = {
        'learning_rate': (0.01,0.2,'uniform'),
        'num_leaves': (30, 50),      
},    
    scoring = 'roc_auc',
    n_jobs = -1, 
    verbose = 0,
    refit = True,
    random_state = 921
)

# Fit the model
result = bayes_cv_tuner.fit(train_features,train_labels, callback=status_print)

# %% [markdown]
# ### 10. 用Grid search微调我们自己模型参数

# %%
def grid_search(param_grid, out_file, BaseParams={}, max_evals = MAX_EVALS):
    """Grid search algorithm (with limit on max evals)
       Writes result of search to csv file every search iteration."""
    
    # Dataframe to store results
    results = pd.DataFrame(columns = ['score', 'params', 'iteration'],
                              index = list(range(MAX_EVALS)))
    
    # https://codereview.stackexchange.com/questions/171173/list-all-possible-permutations-from-a-python-dictionary-of-lists
    keys, values = zip(*param_grid.items())
    
    i = 0
    
    # Iterate through every possible combination of hyperparameters
    for v in itertools.product(*values):
        print('iter:%d'%i)
        # Select the hyperparameters
        parameters = dict(zip(keys, v))
        
        # Set the subsample ratio accounting for boosting type
        #parameters['subsample'] = 1.0 if parameters['boosting_type'] == 'goss' else parameters['subsample']
        BaseParams.update(parameters)
        # Evalute the hyperparameters
        eval_results = objective(BaseParams, i)
        print(eval_results)
        results.loc[i, :] = eval_results
        
        i += 1
        
        # open connection (append option) and write results
        of_connection = open(out_file, 'a')
        writer = csv.writer(of_connection)
        writer.writerow(eval_results)
        
        # make sure to close connection
        of_connection.close()
        
        # Normally would not limit iterations
        if i > MAX_EVALS:
            break
       
    # Sort with best score on top
    results.sort_values('score', ascending = False, inplace = True)
    results.reset_index(inplace = True)
    
    return results

# %%
def random_search(param_grid, out_file, BaseParams={}, max_evals = MAX_EVALS):
    """Random search for hyperparameter optimization. 
       Writes result of search to csv file every search iteration."""
    
    
    # Dataframe for results
    results = pd.DataFrame(columns = ['score', 'params', 'iteration'],
                                  index = list(range(MAX_EVALS)))
    for i in range(MAX_EVALS):
        print('iter:%d'%i)
        # Choose random hyperparameters
        random_params = {k: random.sample(v, 1)[0] for k, v in param_grid.items()}
        #random_params['subsample'] = 1.0 if random_params['boosting_type'] == 'goss' else random_params['subsample']
        BaseParams.update(random_params)
        # Evaluate randomly selected hyperparameters
        eval_results = objective(BaseParams, i)
        results.loc[i, :] = eval_results
        print(eval_results)
        # open connection (append option) and write results
        of_connection = open(out_file, 'a')
        writer = csv.writer(of_connection)
        writer.writerow(eval_results)
        
        # make sure to close connection
        of_connection.close()
        
    # Sort with best score on top
    results.sort_values('score', ascending = False, inplace = True)
    results.reset_index(inplace = True)

    return results

# %%
BaseParams = {  #'random_search_runs': 0,
                      'device': 'cpu', # gpu cpu
                      'num_threads':-1,
                      'boosting_type': 'gbdt',
                      'objective': 'binary',
                      'metric': 'auc',
                      'learning_rate': 0.01291549665014884,
                      'max_bin': 300,
                      'max_depth': -1,
                      'num_leaves': 30,
                      'min_child_samples': 10,
                      'subsample': 1.0,
                      'subsample_freq': 1,
                      'colsample_bytree': 0.01,
                      'min_gain_to_split': 0.30303030303030304,
                      'reg_lambda': 4,
                      'reg_alpha': 0.001,
                      'scale_pos_weight': 1,  
                      'is_unbalance': False}

# %%
param_grid_tmp = {
    'boosting_type': ['gbdt', 'goss', 'dart'],
    'num_leaves': list(range(20, 150)),
    'learning_rate': list(np.logspace(np.log10(0.005), np.log10(0.5), base = 10, num = 1000)),
    'subsample_for_bin': list(range(20000, 300000, 20000)),
    'min_child_samples': list(range(20, 500, 5)),
    'reg_alpha': list(np.linspace(0, 1)),
    'reg_lambda': list(np.linspace(0, 1)),
    'colsample_bytree': list(np.linspace(0.6, 1, 10)),
    'subsample': list(np.linspace(0.5, 1, 100)),
    'is_unbalance': [True, False]
}

# %%
# Hyperparameter grid
param_grid = {
    'min_gain_to_split': list(np.linspace(0, 20,100)),
}
param_grid
# Out:
# {'min_gain_to_split': [0.0,
#   0.30303030303030304,
#   0.6060606060606061,
#   0.9090909090909092,
#   1.2121212121212122,
#   1.5151515151515151,
#   1.8181818181818183,
#   2.121212121212121,
#   2.4242424242424243,
#   2.7272727272727275,
#   3.0303030303030303,
#   3.3333333333333335,
#   3.6363636363636367,
#   3.9393939393939394,
#   4.242424242424242,
#   4.545454545454546,
#   4.848484848484849,
#   5.151515151515151,
#   5.454545454545455,
#   5.757575757575758,
#   6.0606060606060606,
#   6.363636363636364,
#   6.666666666666667,
#   6.96969696969697,
#   7.272727272727273,
#   7.575757575757576,
#   7.878787878787879,
#   8.181818181818182,
#   8.484848484848484,
#   8.787878787878789,
#   9.090909090909092,
#   9.393939393939394,
#   9.696969696969697,
#   10.0,
#   10.303030303030303,
#   10.606060606060606,
#   10.90909090909091,
#   11.212121212121213,
#   11.515151515151516,
#   11.818181818181818,
#   12.121212121212121,
#   12.424242424242424,
#   12.727272727272728,
#   13.030303030303031,
#   13.333333333333334,
#   13.636363636363637,
#   13.93939393939394,
#   14.242424242424242,
#   14.545454545454547,
#   14.84848484848485,
#   15.151515151515152,
#   15.454545454545455,
#   15.757575757575758,
#   16.060606060606062,
#   16.363636363636363,
#   16.666666666666668,
#   16.96969696969697,
#   17.272727272727273,
#   17.575757575757578,
#   17.87878787878788,
#   18.181818181818183,
#   18.484848484848484,
#   18.78787878787879,
#   19.09090909090909,
#   19.393939393939394,
#   19.6969696969697,
#   20.0,
#   20.303030303030305,
#   20.606060606060606,
#   20.90909090909091,
#   21.21212121212121,
#   21.515151515151516,
#   21.81818181818182,
#   22.12121212121212,
#   22.424242424242426,
#   22.727272727272727,
#   23.03030303030303,
#   23.333333333333336,
#   23.636363636363637,
#   23.93939393939394,
#   24.242424242424242,
#   24.545454545454547,
#   24.848484848484848,
#   25.151515151515152,
#   25.454545454545457,
#   25.757575757575758,
#   26.060606060606062,
#   26.363636363636363,
#   26.666666666666668,
#   26.96969696969697,
#   27.272727272727273,
#   27.575757575757578,
#   27.87878787878788,
#   28.181818181818183,
#   28.484848484848484,
#   28.78787878787879,
#   29.090909090909093,
#   29.393939393939394,
#   29.6969696969697,
#   30.0]}

# %%
# Create file and open connection
out_file = 'grid_search_trials_test.csv'
of_connection = open(out_file, 'w')
writer = csv.writer(of_connection)
# Write column names
headers = ['score', 'hyperparameters', 'iteration']
writer.writerow(headers)
of_connection.close()
grid_results = grid_search(param_grid, out_file, BaseParams.copy(),100)
# Out:
# iter:0
# [0.7999043715317578, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 0.0, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 0]
# iter:1
# [0.7999224963428875, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 0.30303030303030304, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 1]
# iter:2
# [0.7997698213596435, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 0.6060606060606061, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 2]
# iter:3
# [0.7997297696797847, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 0.9090909090909092, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 44}, 3]
# iter:4
# [0.7996971408633764, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 1.2121212121212122, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 44}, 4]
# iter:5
# [0.799586054933328, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 1.5151515151515151, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 46}, 5]
# iter:6
# [0.7994608317955615, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 1.8181818181818183, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 44}, 6]
# iter:7
# [0.7994139467265283, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 2.121212121212121, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 7]
# iter:8
# [0.7994866473886931, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 2.4242424242424243, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 8]
# iter:9
# [0.7995663461677361, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 2.7272727272727275, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 9]
# iter:10
# [0.7996083140987522, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 3.0303030303030303, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 10]
# iter:11
# [0.799559611757385, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 3.3333333333333335, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 11]
# iter:12
# [0.7994983895834458, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 3.6363636363636367, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 12]
# iter:13
# [0.7995014666538779, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 3.9393939393939394, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 13]
# iter:14
# [0.7994459827043736, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 4.242424242424242, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 14]
# iter:15
# [0.7994626387959148, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 4.545454545454546, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 15]
# iter:16
# [0.7994541318990656, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 4.848484848484849, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 16]
# iter:17
# [0.7995111094506212, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 5.151515151515151, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 17]
# iter:18
# [0.7995227795487171, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 5.454545454545455, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 18]
# iter:19
# [0.7994950634648256, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 5.757575757575758, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 44}, 19]
# iter:20
# [0.7995073320238983, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 6.0606060606060606, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 44}, 20]
# iter:21
# [0.7994889477155321, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 6.363636363636364, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 44}, 21]
# iter:22
# [0.7995046348424186, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 6.666666666666667, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 63}, 22]
# iter:23
# [0.7995086252905365, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 6.96969696969697, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 23]
# iter:24
# [0.7994846040924484, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 7.272727272727273, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 24]
# iter:25
# [0.7994439007273704, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 7.575757575757576, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 25]
# iter:26
# [0.7994114577445949, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 7.878787878787879, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 145}, 26]
# iter:27
# [0.799386364447064, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 8.181818181818182, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 145}, 27]
# iter:28
# [0.799388064054799, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 8.484848484848484, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 145}, 28]
# iter:29
# [0.7993824533020553, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 8.787878787878789, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 29]
# iter:30
# [0.799411372485446, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 9.090909090909092, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 30]
# iter:31
# [0.7993750927015064, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 9.393939393939394, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 31]
# iter:32
# [0.7993979865522782, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 9.696969696969697, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 32]
# iter:33
# [0.7993821886096917, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 10.0, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 145}, 33]
# iter:34
# [0.7993658919855162, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 10.303030303030303, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 145}, 34]
# iter:35
# [0.799317490888356, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 10.606060606060606, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 35]
# iter:36
# [0.7993404906994798, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 10.90909090909091, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 36]
# iter:37
# [0.799340654039355, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 11.212121212121213, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 37]
# iter:38
# [0.7993248017875588, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 11.515151515151516, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 38]
# iter:39
# [0.7993022009511035, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 11.818181818181818, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 39]
# iter:40
# [0.799295532115983, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 12.121212121212121, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 42}, 40]
# iter:41
# [0.799284671711123, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 12.424242424242424, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 147}, 41]
# iter:42
# [0.7993146405104538, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 12.727272727272728, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 147}, 42]
# iter:43
# [0.7993187263645917, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 13.030303030303031, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 147}, 43]
# iter:44
# [0.7992770893950842, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 13.333333333333334, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 147}, 44]
# iter:45
# [0.7992442790315868, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 13.636363636363637, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 145}, 45]
# iter:46
# [0.7992074802032668, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 13.93939393939394, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 145}, 46]
# iter:47
# [0.7992028475536511, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 14.242424242424242, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 147}, 47]
# iter:48
# [0.7991604625501384, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 14.545454545454547, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 147}, 48]
# iter:49
# [0.7991803446322453, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 14.84848484848485, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 147}, 49]
# iter:50
# [0.7991687761395918, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 15.151515151515152, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 147}, 50]
# iter:51
# [0.799168088735226, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 15.454545454545455, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 147}, 51]
# iter:52
# [0.7991798760685824, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 15.757575757575758, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 147}, 52]
# iter:53
# [0.7991422651685761, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 16.060606060606062, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 147}, 53]
# iter:54
# [0.7991494866430939, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 16.363636363636363, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}, 54]
# iter:55
# [0.7991998991184982, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 16.666666666666668, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 598}, 55]
# iter:56
# [0.7991997118252528, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 16.96969696969697, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 598}, 56]
# iter:57
# [0.7991562111246615, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 17.272727272727273, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}, 57]
# iter:58
# [0.7991847276703374, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 17.575757575757578, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 598}, 58]
# iter:59
# [0.7991998449938768, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 17.87878787878788, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}, 59]
# iter:60
# [0.7992343479432451, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 18.181818181818183, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 159}, 60]
# iter:61
# [0.7991965066692037, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 18.484848484848484, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 159}, 61]
# iter:62
# [0.7992241587243016, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 18.78787878787879, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 159}, 62]
# iter:63
# [0.7992779805599965, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 19.09090909090909, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 159}, 63]
# iter:64
# [0.7992887264013364, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 19.393939393939394, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 158}, 64]
# iter:65
# [0.7992978471134665, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 19.6969696969697, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 158}, 65]
# iter:66
# [0.7992117396330265, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 20.0, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 159}, 66]
# iter:67
# [0.7992518229355452, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 20.303030303030305, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 159}, 67]
# iter:68
# [0.7992090049521516, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 20.606060606060606, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 175}, 68]
# iter:69
# [0.7992810489766693, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 20.90909090909091, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 158}, 69]
# iter:70
# [0.7992639432526742, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 21.21212121212121, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 158}, 70]
# iter:71
# [0.7992693573815911, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 21.515151515151516, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 158}, 71]
# iter:72
# [0.7991974567211082, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 21.81818181818182, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 158}, 72]
# iter:73
# [0.7992103974929538, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 22.12121212121212, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}, 73]
# iter:74
# [0.7992565996875477, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 22.424242424242426, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}, 74]
# iter:75
# [0.7992678864913844, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 22.727272727272727, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}, 75]
# iter:76
# [0.7993055806487851, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 23.03030303030303, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 155}, 76]
# iter:77
# [0.799310327781933, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 23.333333333333336, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}, 77]
# iter:78
# [0.7992864549132968, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 23.636363636363637, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}, 78]
# iter:79
# [0.7993497140281842, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 23.93939393939394, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}, 79]
# iter:80
# [0.7993657640509879, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 24.242424242424242, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 155}, 80]
# iter:81
# [0.7993685006850774, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 24.545454545454547, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 156}, 81]
# iter:82
# [0.7994011264906502, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 24.848484848484848, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 164}, 82]
# iter:83
# [0.7994113359274496, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 25.151515151515152, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 156}, 83]
# iter:84
# [0.7993370059814777, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 25.454545454545457, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 164}, 84]
# iter:85
# [0.7993532876157398, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 25.757575757575758, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}, 85]
# iter:86
# [0.7993959095215499, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 26.060606060606062, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}, 86]
# iter:87
# [0.7993318708046898, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 26.363636363636363, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}, 87]
# iter:88
# [0.7992966760830568, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 26.666666666666668, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}, 88]
# iter:89
# [0.7992990164155857, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 26.96969696969697, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}, 89]
# iter:90
# [0.7993504172715682, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 27.272727272727273, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 161}, 90]
# iter:91
# [0.7993508901224583, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 27.575757575757578, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 180}, 91]
# iter:92
# [0.7993459783580029, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 27.87878787878788, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}, 92]
# iter:93
# [0.7993966404319411, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 28.181818181818183, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}, 93]
# iter:94
# [0.7994102941339392, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 28.484848484848484, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 180}, 94]
# iter:95
# [0.7994128646436092, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 28.78787878787879, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 180}, 95]
# iter:96
# [0.7994108742783168, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 29.090909090909093, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}, 96]
# iter:97
# [0.7993991756087322, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 29.393939393939394, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}, 97]
# iter:98
# [0.7994371533575737, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 29.6969696969697, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}, 98]
# iter:99
# [0.7994620586686286, {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 30.0, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}, 99]

# %%
grid_results.head()
# Out:
#    index     score  \
# 0      1  0.799922
# 1      0  0.799904
# 2      2   0.79977
# 3      3   0.79973
# 4      4  0.799697
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                       params  \
# 0  {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 30.0, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}
# 1  {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 30.0, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}
# 2  {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 30.0, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}
# 3  {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 30.0, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}
# 4  {'device': 'cpu', 'num_threads': -1, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.01291549665014884, 'max_bin': 300, 'max_depth': -1, 'num_leaves': 30, 'min_child_samples': 10, 'subsample': 1.0, 'subsample_freq': 1, 'colsample_bytree': 0.01, 'min_gain_to_split': 30.0, 'reg_lambda': 4, 'reg_alpha': 0.001, 'scale_pos_weight': 1, 'is_unbalance': False, 'verbose': 1, 'n_estimators': 181}
#
#   iteration
# 0         1
# 1         0
# 2         2
# 3         3
# 4         4
