# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
import xgboost as xgb
from xgboost import XGBClassifier
import os
import gc
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn.model_selection import GridSearchCV
from skopt import BayesSearchCV
import lightgbm as lgb
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.feature_selection import VarianceThreshold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
OriginDataDir = '/home/songyue/homeCredit/HomeCreditDefaultRisk/Data/OriginData'
TrainTestDataDir = '/home/songyue/homeCredit/HomeCreditDefaultRisk/Data/TrainTestData'
ModelSaveDir = '/home/songyue/homeCredit/HomeCreditDefaultRisk/Models/XGBoost/models'
ResultSaveDir = '/home/songyue/homeCredit/HomeCreditDefaultRisk/Models/XGBoost/result'

# %%
def loadData(DataName):
    DataPath = os.path.join(TrainTestDataDir, DataName)
    if not os.path.exists(DataPath):
        print('%s does not exist!' % DataPath)
        return
    OriginData = pd.read_csv(DataPath, index_col=0)
    #OriginData = OriginData.sample(frac=1)  # 打乱顺序后返回
    return OriginData


def NormalData(TrainData, TestData):
    # 对一些列的均值大于100的进行归一化处理
    AllData = TrainData.append(TestData)
    for col in AllData.columns:
        if abs(AllData[col].mean())>1:
            scaler = StandardScaler().fit(np.atleast_2d(AllData[col]).T)
            TrainData[col] = scaler.transform(np.atleast_2d(TrainData[col]).T)
    return TrainData

# %%
def status_print(optim_result):
    """Status callback durring bayesian hyperparameter search"""
    
    # Get all the models tested so far in DataFrame format
    all_models = pd.DataFrame(bayes_cv_tuner.cv_results_)    
    
    # Get current parameters and the best parameters    
    best_params = pd.Series(bayes_cv_tuner.best_params_)
    print('Model #{}\nBest ROC-AUC: {}\nBest params: {}\n'.format(
        len(all_models),
        np.round(bayes_cv_tuner.best_score_, 4),
        bayes_cv_tuner.best_params_
    ))
    
    # Save all model results
    clf_name = bayes_cv_tuner.estimator.__class__.__name__
    all_models.to_csv(clf_name+"_cv_results.csv")

# %%
TestData = loadData('AllTest_withnull.csv')
TestID = TestData.SK_ID_CURR.values
TestData.drop('SK_ID_CURR', axis=1, inplace=True)
AllTrainData = loadData('AllTrain_withnull.csv')
AllTrainData.reset_index(drop=True, inplace=True)
AllTrainData.drop('SK_ID_CURR', axis=1, inplace=True)

# %%
AllTrainData.shape
# Out:
# (307511, 1100)

# %%
TestData.shape
# Out:
# (48744, 1099)

# %%
features = [x for x in AllTrainData.columns if x != 'TARGET' and x != 'SK_ID_CURR']

# %%
len(features)
# Out:
# 1099

# %%
lgbm_params = {
    "boosting":"dart",
    "application":"binary",
    "learning_rate": 0.1,
    'reg_alpha':0.041545473,
    'reg_lambda': 0.0735294,
    "n_estimators":10000,
    "max_depth":8,
    "num_leaves":34,
    "max_bin":225,
    "colsample_bytree":0.9497036,
    "subsample":0.8715623,
    "min_split_gain":0.0222415,
    "min_child_weight":39.3259775
}

# %%
model = lgb.LGBMClassifier(application="binary", boosting_type=lgbm_params["boosting"],
                          learning_rate=lgbm_params["learning_rate"],n_estimators=lgbm_params["n_estimators"],
                          num_leaves=lgbm_params["num_leaves"], max_depth=lgbm_params["max_depth"],
                          max_bin=lgbm_params["max_bin"], num_threads =-1,colsample_bytree=lgbm_params["colsample_bytree"],
                          subsample=lgbm_params["subsample"],min_split_gain=lgbm_params["min_split_gain"],
                          min_child_weight=lgbm_params["min_child_weight"])
#                           min_data_in_leaf=lgbm_params["min_data_in_leaf"],
#                            feature_fraction=lgbm_params["feature_fraction"],

# %%
feature_importances = np.zeros(len(features))
for i in range(2):
    train_data, test_data, train_y, test_y = train_test_split(AllTrainData[features],AllTrainData['TARGET']
                                                              ,test_size=0.2, random_state=i)
    model.fit(train_data, train_y, early_stopping_rounds=200, 
              eval_set=[(test_data, test_y)], eval_metric='auc', verbose=200)
    feature_importances += model.feature_importances_
# Out:
# Training until validation scores don't improve for 200 rounds.
# [200]	valid_0's auc: 0.750077
# --------------------------------------------------------------------
# KeyboardInterrupt                  Traceback (most recent call last)
# <ipython-input-16-e1d898a0af4b> in <module>()
#       4                                                               ,test_size=0.2, random_state=i)
#       5     model.fit(train_data, train_y, early_stopping_rounds=200,
# ----> 6               eval_set=[(test_data, test_y)], eval_metric='auc', verbose=200)
#       7     feature_importances += model.feature_importances_
#
# /usr/share/anaconda2/envs/py3/lib/python3.5/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     693                                         verbose=verbose, feature_name=feature_name,
#     694                                         categorical_feature=categorical_feature,
# --> 695                                         callbacks=callbacks)
#     696         return self
#     697
#
# /usr/share/anaconda2/envs/py3/lib/python3.5/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     472                               verbose_eval=verbose, feature_name=feature_name,
#     473                               categorical_feature=categorical_feature,
# --> 474                               callbacks=callbacks)
#     475
#     476         if evals_result:
#
# /usr/share/anaconda2/envs/py3/lib/python3.5/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     202                                     evaluation_result_list=None))
#     203
# --> 204         booster.update(fobj=fobj)
#     205
#     206         evaluation_result_list = []
#
# /usr/share/anaconda2/envs/py3/lib/python3.5/site-packages/lightgbm/basic.py in update(self, train_set, fobj)
#    1526             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1527                 self.handle,
# -> 1528                 ctypes.byref(is_finished)))
#    1529             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1530             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
feature_importances = feature_importances/2
feature_importances = pd.DataFrame({'feature': features, 'importance': feature_importances}).sort_values('importance', ascending = False)

feature_importances.head(30)
# Out:
#                              feature  importance
# 49                   EXT_SOURCE_MEAN       468.5
# 10                        DAYS_BIRTH       356.0
# 31                      EXT_SOURCE_1       253.0
# 785        NEW_CREDIT_TO_GOODS_RATIO       238.5
# 7                        AMT_ANNUITY       238.0
# 784      NEW_CREDIT_TO_ANNUITY_RATIO       234.5
# 33                      EXT_SOURCE_3       220.5
# 251                  DAYS_CREDIT_max       219.5
# 13                   DAYS_ID_PUBLISH       202.5
# 54                   EXT_SOURCE_PROD       189.5
# 53                    EXT_SOURCE_MIN       184.5
# 32                      EXT_SOURCE_2       184.0
# 786        NEW_EMPLOY_TO_BIRTH_RATIO       178.5
# 793           INSTAL_AMT_PAYMENT_SUM       176.0
# 843            DEBT_CREDIT_RATIO_new       165.5
# 791      NEW_ANNUITY_TO_INCOME_RATIO       165.0
# 50                    EXT_SOURCE_STD       161.0
# 811                   CREDIT_TERM_sy       161.0
# 12                 DAYS_REGISTRATION       157.0
# 225            DAYS_ENDDATE_FACT_max       153.0
# 372    DAYS_INSTALMENT_minus_max_min       149.0
# 812               CREDIT_TERM_INV_sy       145.0
# 787          ACTIVE_DAYS_CREDIT_MEAN       136.5
# 806        PREV_APP_CREDIT_PERC_MEAN       136.5
# 788  ACTIVE_DAYS_CREDIT_ENDDATE_MEAN       132.5
# 790    INSTAL_DAYS_ENTRY_PAYMENT_MAX       132.0
# 237          DAYS_CREDIT_ENDDATE_max       131.0
# 799        ACTIVE_AMT_CREDIT_SUM_SUM       130.5
# 8                    AMT_GOODS_PRICE       130.0
# 373   DAYS_INSTALMENT_minus_max_mean       129.5

# %%
zero_features = list(feature_importances[feature_importances['importance'] == 0.0]['feature'])
print('There are %d features with 0.0 importance' % len(zero_features))
feature_importances.tail(32)
# Out:
# There are 196 features with 0.0 importance
#                                          feature  importance
# 553             CNT_DRAWINGS_ATM_CURRENT_min_max         0.0
# 551           CNT_DRAWINGS_OTHER_CURRENT_max_max         0.0
# 550          CNT_DRAWINGS_OTHER_CURRENT_max_mean         0.0
# 547           CNT_DRAWINGS_OTHER_CURRENT_min_max         0.0
# 546          CNT_DRAWINGS_OTHER_CURRENT_min_mean         0.0
# 541             CNT_DRAWINGS_POS_CURRENT_min_max         0.0
# 537          NAME_CONTRACT_STATUS_Signed_sum_max         0.0
# 158          ORGANIZATION_TYPE_Industry: type 12         0.0
# 535   NAME_CONTRACT_STATUS_Sent proposal_sum_max         0.0
# 534  NAME_CONTRACT_STATUS_Sent proposal_sum_mean         0.0
# 533         NAME_CONTRACT_STATUS_Refused_sum_max         0.0
# 532        NAME_CONTRACT_STATUS_Refused_sum_mean         0.0
# 531          NAME_CONTRACT_STATUS_Demand_sum_max         0.0
# 530         NAME_CONTRACT_STATUS_Demand_sum_mean         0.0
# 170             ORGANIZATION_TYPE_Legal Services         0.0
# 570                AMT_TOTAL_RECEIVABLE_min_mean         0.0
# 572               AMT_TOTAL_RECEIVABLE_mean_mean         0.0
# 576                AMT_DRAWINGS_CURRENT_min_mean         0.0
# 577                 AMT_DRAWINGS_CURRENT_min_max         0.0
# 168                  ORGANIZATION_TYPE_Insurance         0.0
# 582          AMT_DRAWINGS_OTHER_CURRENT_min_mean         0.0
# 583           AMT_DRAWINGS_OTHER_CURRENT_min_max         0.0
# 166           ORGANIZATION_TYPE_Industry: type 8         0.0
# 595                       MONTHS_BALANCE_min_max         0.0
# 165           ORGANIZATION_TYPE_Industry: type 7         0.0
# 164           ORGANIZATION_TYPE_Industry: type 6         0.0
# 163           ORGANIZATION_TYPE_Industry: type 5         0.0
# 162           ORGANIZATION_TYPE_Industry: type 4         0.0
# 608            AMT_DRAWINGS_ATM_CURRENT_min_mean         0.0
# 160           ORGANIZATION_TYPE_Industry: type 2         0.0
# 159          ORGANIZATION_TYPE_Industry: type 13         0.0
# 846                 AVG_CREDITDAYS_PROLONGED_new         0.0

# %%
def plot_feature_importances(df, threshold=0.98):
    
    plt.rcParams["font.size"] = 20
    
    df = df.sort_values('importance', ascending=False).reset_index()
    
    df['importance_normalized'] = df['importance']/df['importance'].sum()
    df['cumulative_importance'] = np.cumsum(df['importance_normalized'])
    
    plt.figure(figsize=(10,10))
    ax = plt.subplot()
    
    ax.barh(list(reversed(list(df.index[:30]))),
            df['importance_normalized'].head(30),
            align='center', edgecolor='k')
    ax.set_yticks(list(reversed(list(df.index[:30]))))
    ax.set_yticklabels(df['feature'].head(30))
    plt.xlabel('Normalized Importance'); plt.title('Feature Importances')
    plt.show()
    
    plt.figure(figsize=(8,6))
    plt.plot(list(range(len(df))), df['cumulative_importance'], 'r-')
    plt.xlabel('Number of features');plt.ylabel('Cumulative Importances');
    
    plt.title("Cumulative Feature Importance");
    plt.show()
    
    importance_index = np.min(np.where(df['cumulative_importance'] > threshold))
    print('%d features required for %0.2f of cumulative importance' % (importance_index + 1, threshold))
    
    return df

# %%
norm_feature_importances = plot_feature_importances(feature_importances)
# Out:
# 466 features required for 0.98 of cumulative importance

# %%
threshold = 0.98

features_to_keep = list(norm_feature_importances[norm_feature_importances['cumulative_importance'] < threshold]['feature'])

# %%
print('Training shape: ', data.shape)
print('Testing shape: ', test.shape)
# Out:
# Training shape:  (307511, 1099)
# Testing shape:  (48744, 1099)

# %%
data = AllTrainData[features]
test  = TestData[features]

# %%
n_folds = 5
k_fold = KFold(n_splits=n_folds, shuffle=False, random_state=47)

feature_importances_values = np.zeros(data.shape[1])

test_predictions = np.zeros(test.shape[0])
out_of_fold = np.zeros(data.shape[0])

valid_scores = []
train_scores = []

for train_indices, test_indices in k_fold.split(data):
    
    train_data, train_y = AllTrainData[features].iloc[train_indices], AllTrainData.TARGET.iloc[train_indices]
    test_data, test_y = AllTrainData[features].iloc[test_indices], AllTrainData.TARGET.iloc[test_indices]
    
    model = lgb.LGBMClassifier(application="binary", boosting_type=lgbm_params["boosting"],
                          learning_rate=lgbm_params["learning_rate"],n_estimators=lgbm_params["n_estimators"],
                          num_leaves=lgbm_params["num_leaves"], max_depth=lgbm_params["max_depth"],
                          max_bin=lgbm_params["max_bin"], num_threads =-1,colsample_bytree=lgbm_params["colsample_bytree"],
                          subsample=lgbm_params["subsample"],min_split_gain=lgbm_params["min_split_gain"],
                          min_child_weight=lgbm_params["min_child_weight"])
    
    model.fit(train_data, train_y, eval_metric='auc', eval_set=[(test_data, test_y), (train_data, train_y)],
              eval_names=['valid', 'train'], early_stopping_rounds=200, verbose=200)
    
    best_iteration = model.best_iteration_
    feature_importances_values += model.feature_importances_ / k_fold.n_splits
    
    test_predictions += model.predict_proba(test, num_iteration=best_iteration)[:,1]/k_fold.n_splits
    
    out_of_fold[test_indices] = model.predict_proba(test_data, num_iteration = best_iteration)[:, 1]
        
        # Record the best score
    valid_score = model.best_score_['valid']['auc']
    train_score = model.best_score_['train']['auc']
        
    valid_scores.append(valid_score)
    train_scores.append(train_score)
        
    gc.enable()
    del model, train_data, test_data
    gc.collect()
# Out:
# Training until validation scores don't improve for 200 rounds.
# [200]	train's auc: 0.817234	valid's auc: 0.77871
# [400]	train's auc: 0.848205	valid's auc: 0.78731
# [600]	train's auc: 0.870359	valid's auc: 0.788915
# [800]	train's auc: 0.886635	valid's auc: 0.790643
# Early stopping, best iteration is:
# [795]	train's auc: 0.886594	valid's auc: 0.790665
# --------------------------------------------------------------------
# KeyboardInterrupt                  Traceback (most recent call last)
# <ipython-input-21-ef58fcd0339b> in <module>()
#      30     test_predictions += model.predict_proba(test, num_iteration=best_iteration)[:,1]/k_fold.n_splits
#      31
# ---> 32     out_of_fold[test_indices] = model.predict_proba(test_data, num_iteration = best_iteration)[:, 1]
#      33
#      34         # Record the best score
#
# /usr/share/anaconda2/envs/py3/lib/python3.5/site-packages/lightgbm/sklearn.py in predict_proba(self, X, raw_score, num_iteration, pred_leaf, pred_contrib, **kwargs)
#     740         """
#     741         result = super(LGBMClassifier, self).predict(X, raw_score, num_iteration,
# --> 742                                                      pred_leaf, pred_contrib, **kwargs)
#     743         if self._n_classes > 2 or pred_leaf or pred_contrib:
#     744             return result
#
# /usr/share/anaconda2/envs/py3/lib/python3.5/site-packages/lightgbm/sklearn.py in predict(self, X, raw_score, num_iteration, pred_leaf, pred_contrib, **kwargs)
#     526                              % (self._n_features, n_features))
#     527         return self.booster_.predict(X, raw_score=raw_score, num_iteration=num_iteration,
# --> 528                                      pred_leaf=pred_leaf, pred_contrib=pred_contrib, **kwargs)
#     529
#     530     def apply(self, X, num_iteration=0):
#
# /usr/share/anaconda2/envs/py3/lib/python3.5/site-packages/lightgbm/basic.py in predict(self, data, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape, pred_parameter, **kwargs)
#    1800         if num_iteration <= 0:
#    1801             num_iteration = self.best_iteration
# -> 1802         return predictor.predict(data, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape)
#    1803
#    1804     def get_leaf_output(self, tree_id, leaf_id):
#
# /usr/share/anaconda2/envs/py3/lib/python3.5/site-packages/lightgbm/basic.py in predict(self, data, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape)
#     438         elif isinstance(data, np.ndarray):
#     439             preds, nrow = self.__pred_for_np2d(data, num_iteration,
# --> 440                                                predict_type)
#     441         elif isinstance(data, list):
#     442             try:
#
# /usr/share/anaconda2/envs/py3/lib/python3.5/site-packages/lightgbm/basic.py in __pred_for_np2d(self, mat, num_iteration, predict_type)
#     485
#     486         if mat.dtype == np.float32 or mat.dtype == np.float64:
# --> 487             data = np.array(mat.reshape(mat.size), dtype=mat.dtype, copy=False)
#     488         else:
#     489             """change non-float data to float data, need to copy"""
#
# KeyboardInterrupt:

# %%
submission = pd.DataFrame({'SK_ID_CURR': TestID, 'TARGET': test_predictions})
submission.to_csv("submissions_lgbm.csv", index=False)

# %%
data.columns
# Out:
# Index(['NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY',
#        'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY',
#        'AMT_GOODS_PRICE', 'REGION_POPULATION_RELATIVE',
#        ...
#        '12_period_trend_SK_DPD', '12_period_trend_SK_DPD_DEF',
#        '1_period_trend_SK_DPD', '1_period_trend_SK_DPD_DEF',
#        '30_period_trend_SK_DPD', '30_period_trend_SK_DPD_DEF',
#        '60_period_trend_SK_DPD', '60_period_trend_SK_DPD_DEF',
#        '6_period_trend_SK_DPD', '6_period_trend_SK_DPD_DEF'],
#       dtype='object', length=1099)

# %%
n_folds = 5
k_fold = KFold(n_splits=n_folds, shuffle=True, random_state=90210)

feature_importances_values = np.zeros(data.shape[1])

test_predictions = np.zeros(test.shape[0])
out_of_fold = np.zeros(data.shape[0])

valid_scores = []
train_scores = []

for train_indices, test_indices in k_fold.split(AllTrainData[features],AllTrainData.TARGET):
    
    train_data, train_y = AllTrainData[features].iloc[train_indices], AllTrainData.TARGET.iloc[train_indices]
    test_data, test_y = AllTrainData[features].iloc[test_indices], AllTrainData.TARGET.iloc[test_indices]
    
    model = lgb.LGBMClassifier(is_unbalance=False,
                               scale_pos_weight = 1,
                               reg_alpha=0.0,
                               reg_lambda=100,
                               min_split_gain=0.5,
                               colsample_bytree=0.05,
                               subsample_freq=1,
                               subsample=1.0,
                               min_child_samples=70,
                               num_leaves=30,
                               max_depth=-1,
                               max_bin=300,
                               learning_rate=0.02,
                               n_estimators=10000,
                               boosting_type='gbdt',
                               application="binary",
                              )
    
    model.fit(train_data, train_y, eval_metric='auc', eval_set=[(test_data, test_y), (train_data, train_y)],
              eval_names=['valid', 'train'], early_stopping_rounds=200, verbose=200)
    
    best_iteration = model.best_iteration_
    feature_importances_values += model.feature_importances_ / k_fold.n_splits
    
    test_predictions += model.predict_proba(test, num_iteration=best_iteration)[:,1]/k_fold.n_splits
    
    out_of_fold[test_indices] = model.predict_proba(test_data, num_iteration = best_iteration)[:, 1]
        
        # Record the best score
    valid_score = model.best_score_['valid']['auc']
    train_score = model.best_score_['train']['auc']
        
    valid_scores.append(valid_score)
    train_scores.append(train_score)
        
    gc.enable()
    del model, train_data, test_data
    gc.collect()
# Out:
# Training until validation scores don't improve for 200 rounds.
# [200]	train's auc: 0.78819	valid's auc: 0.775924
# [400]	train's auc: 0.804449	valid's auc: 0.783614
# [600]	train's auc: 0.816282	valid's auc: 0.787882
# [800]	train's auc: 0.825856	valid's auc: 0.790138
# [1000]	train's auc: 0.834249	valid's auc: 0.79162
# [1200]	train's auc: 0.841825	valid's auc: 0.792568
# [1400]	train's auc: 0.84866	valid's auc: 0.793157
# [1600]	train's auc: 0.854905	valid's auc: 0.793703
# [1800]	train's auc: 0.860802	valid's auc: 0.793795
# [2000]	train's auc: 0.866055	valid's auc: 0.793884
# [2200]	train's auc: 0.870939	valid's auc: 0.793991
# [2400]	train's auc: 0.875672	valid's auc: 0.794226
# [2600]	train's auc: 0.880052	valid's auc: 0.794247
# Early stopping, best iteration is:
# [2410]	train's auc: 0.87588	valid's auc: 0.794272
# Training until validation scores don't improve for 200 rounds.
# [200]	train's auc: 0.789225	valid's auc: 0.771535
# [400]	train's auc: 0.805144	valid's auc: 0.780326
# [600]	train's auc: 0.816774	valid's auc: 0.785336
# [800]	train's auc: 0.826239	valid's auc: 0.788258
# --------------------------------------------------------------------
# KeyboardInterrupt                  Traceback (most recent call last)
# <ipython-input-34-dfbe785d3372> in <module>()
#      34
#      35     model.fit(train_data, train_y, eval_metric='auc', eval_set=[(test_data, test_y), (train_data, train_y)],
# ---> 36               eval_names=['valid', 'train'], early_stopping_rounds=200, verbose=200)
#      37
#      38     best_iteration = model.best_iteration_
#
# /usr/share/anaconda2/envs/py3/lib/python3.5/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     693                                         verbose=verbose, feature_name=feature_name,
#     694                                         categorical_feature=categorical_feature,
# --> 695                                         callbacks=callbacks)
#     696         return self
#     697
#
# /usr/share/anaconda2/envs/py3/lib/python3.5/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     472                               verbose_eval=verbose, feature_name=feature_name,
#     473                               categorical_feature=categorical_feature,
# --> 474                               callbacks=callbacks)
#     475
#     476         if evals_result:
#
# /usr/share/anaconda2/envs/py3/lib/python3.5/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     202                                     evaluation_result_list=None))
#     203
# --> 204         booster.update(fobj=fobj)
#     205
#     206         evaluation_result_list = []
#
# /usr/share/anaconda2/envs/py3/lib/python3.5/site-packages/lightgbm/basic.py in update(self, train_set, fobj)
#    1526             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1527                 self.handle,
# -> 1528                 ctypes.byref(is_finished)))
#    1529             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1530             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
feature_importances = pd.DataFrame({'feature': features, 'importance': feature_importances_values}).sort_values('importance', ascending = False)
feature_importances.head(50)
# Out:
#                                       feature  importance
# 812                        CREDIT_TERM_INV_sy       642.0
# 811                            CREDIT_TERM_sy       504.4
# 784               NEW_CREDIT_TO_ANNUITY_RATIO       468.6
# 10                                 DAYS_BIRTH       444.8
# 237                   DAYS_CREDIT_ENDDATE_max       385.8
# 33                               EXT_SOURCE_3       378.0
# 225                     DAYS_ENDDATE_FACT_max       326.0
# 8                             AMT_GOODS_PRICE       325.2
# 843                     DEBT_CREDIT_RATIO_new       325.0
# 790             INSTAL_DAYS_ENTRY_PAYMENT_MAX       300.2
# 785                 NEW_CREDIT_TO_GOODS_RATIO       300.0
# 50                             EXT_SOURCE_STD       296.2
# 251                           DAYS_CREDIT_max       296.0
# 788           ACTIVE_DAYS_CREDIT_ENDDATE_MEAN       291.4
# 989  OCCUPATION_TYPE_mean_DAYS_BIRTH_abs_diff       281.4
# 32                               EXT_SOURCE_2       279.8
# 241                        AMT_CREDIT_SUM_max       271.0
# 988      OCCUPATION_TYPE_mean_DAYS_BIRTH_diff       269.6
# 787                   ACTIVE_DAYS_CREDIT_MEAN       259.4
# 847            EXT_SOURCE_MEAN_div_DAYS_BIRTH       257.4
# 869      EXT_SOURCE_MEAN_multiply_AMT_ANNUITY       256.6
# 852            AMT_CREDIT_div_DAYS_CREDIT_max       253.8
# 53                             EXT_SOURCE_MIN       252.0
# 786                 NEW_EMPLOY_TO_BIRTH_RATIO       250.6
# 868   EXT_SOURCE_MEAN_multiply_CREDIT_TERM_sy       249.8
# 353               AMT_PAYMENT_minus_mean_mean       249.6
# 376             DAYS_INSTALMENT_minus_std_min       249.6
# 13                            DAYS_ID_PUBLISH       249.4
# 9                  REGION_POPULATION_RELATIVE       248.4
# 49                            EXT_SOURCE_MEAN       247.6
# 850          AMT_ANNUNITY_div_DAYS_CREDIT_max       247.6
# 867       EXT_SOURCE_MEAN_multiply_DAYS_BIRTH       242.6
# 52                             EXT_SOURCE_MAX       241.4
# 370            DAYS_INSTALMENT_minus_mean_max       241.4
# 797                CLOSED_AMT_CREDIT_SUM_MEAN       239.8
# 801            ACTIVE_DAYS_CREDIT_UPDATE_MEAN       239.0
# 796                            INSTAL_DBD_SUM       238.4
# 806                 PREV_APP_CREDIT_PERC_MEAN       238.2
# 875  ACTIVE_AMT_CREDIT_SUM_SUM_div_DAYS_BIRTH       237.8
# 661                      SELLERPLACE_AREA_sum       235.6
# 876                            EXT_SOURCE_gap       234.6
# 368            DAYS_INSTALMENT_minus_mean_min       232.2
# 54                            EXT_SOURCE_PROD       229.8
# 239                       AMT_CREDIT_SUM_mean       229.0
# 497                     AMT_DOWN_PAYMENT_mean       226.6
# 799                 ACTIVE_AMT_CREDIT_SUM_SUM       226.0
# 666                         DAYS_LAST_DUE_sum       225.6
# 824   AMT_CREDIT_SUM_DEBT_mean_INCOME_PERCENT       224.4
# 242                        AMT_CREDIT_SUM_min       224.0
# 892                      EXT_SOURCE_nanmedian       223.8

# %%
submission = pd.DataFrame({'SK_ID_CURR': TestID, 'TARGET': test_predictions})
submission.to_csv("lgbm_test1.csv", index=False)

# %%
submission.head()
# Out:
#    SK_ID_CURR    TARGET
# 0      100001  0.045261
# 1      100005  0.123637
# 2      100013  0.034818
# 3      100028  0.035249
# 4      100038  0.140429
